# %%
import numpy as np
import pandas as pd

import networkx as nx 
from pyvis import network as net

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Utility functions

# %%
def add_node_colors(network, col_attribute, cmap_name="Accent"):
    """
    Function to add node colors based on existing node attribute.
    
    network: networkx object
    col_attribute: Name of attribute to use for determining node colors
    cmap_name: Name of matplotlib colormap to use (default: 'Accent')
    
    """
    source_att = nx.get_node_attributes(network, col_attribute)
    
    # Get colors
    cmap = cm.get_cmap(cmap_name, len(set(source_att.values())))    
    source_dict = dict(zip(list(set(source_att.values())),
                           np.arange(len(set(source_att.values())))))
    node_colors = {n:mpl.colors.rgb2hex(cmap(source_dict[v]), keep_alpha=True) for (n, v) in source_att.items()}

    # Set colors
    nx.set_node_attributes(network, node_colors, 'color')

# %% [markdown]
# # Example with new networkx object

# %%
# Generate fake adjacency matrix from proteomics data with real data attributes

proteomics = pd.read_csv('/nfs/answer/fraenkel_internal/current_omics/proteomics/normalized_imp_corrected_proteomics204_03292022.csv',
                        index_col=0)
metadata = pd.read_csv('/nfs/answer/fraenkel_internal/current_omics/proteomics/full_prot_metadata203_03082023.csv',
                      index_col=0)
proteomics = proteomics.loc[:,metadata.GUID.values]

num_guids = proteomics.shape[1]
print(num_guids)
proteomics
# Out:
# 203
#               NEUAB000NKC  NEUAE993EPR  NEUAF553MJ3  NEUAG241NUD  NEUAG603XLK  \
# A0FGR8|ESYT2    12.472100    12.642798    12.742081    12.481972    12.552721
# A0MZ66|SHOT1    13.842471    13.975695    13.699891    13.856147    13.816688
# A1L020|MEX3A    13.296923    13.293507    13.398688    13.544040    13.342870
# A1X283|SPD2B    12.470363    12.411420    12.515813    12.641331    12.584407
# A2RRP1|NBAS     11.340363    10.749392    11.003630    10.760671    10.877956
# ...                   ...          ...          ...          ...          ...
# Q9Y6R0|NUMBL    11.483020    11.542400    11.533970    11.655710    11.382800
# Q9Y6V0|PCLO      9.456830     9.557025     9.794867     9.345021     9.363582
# Q9Y6V7|DDX49    11.058880    11.030750    11.481060    11.313340    11.329190
# Q9Y6X4|F169A    10.503000    10.836080    10.431840    10.841550    10.704220
# Q9Y6Y0|NS1BP    11.823490    11.371910    11.858090    11.668360    11.617550
#
#               NEUAJ928PAA  NEUAL076FCE  NEUAP285GGU  NEUAT234RK6  NEUAW717TN6  \
# A0FGR8|ESYT2    12.579313    12.850728    12.639461    12.698320    12.550657
# A0MZ66|SHOT1    13.735516    14.050555    13.870213    14.164351    13.929244
# A1L020|MEX3A    13.575677    13.495929    13.411647    13.205646    13.362286
# A1X283|SPD2B    12.361021    12.528692    12.220873    12.444753    12.631653
# A2RRP1|NBAS     10.477362    10.272972    10.272276    10.897402    10.853940
# ...                   ...          ...          ...          ...          ...
# Q9Y6R0|NUMBL    11.350170    11.779620    11.489790    11.358130    11.576580
# Q9Y6V0|PCLO      9.752151     9.579164     9.806852     9.462755     9.562161
# Q9Y6V7|DDX49    11.151840    11.214950    11.275310    10.891840    11.190700
# Q9Y6X4|F169A    10.887090    10.954850    10.658110    10.977600    10.921100
# Q9Y6Y0|NS1BP    11.581350    11.848710    11.427130    11.495000    11.609580
#
#               ...  NEUZK054DP5  NEUZL045YD3  NEUZN936HJ9  NEUZP278MR4  \
# A0FGR8|ESYT2  ...    12.262520    12.450807    12.641901    12.717533
# A0MZ66|SHOT1  ...    14.325582    13.957713    13.991507    13.892948
# A1L020|MEX3A  ...    13.528092    13.310814    13.350540    13.616407
# A1X283|SPD2B  ...    12.512905    12.302379    12.490169    12.335576
# A2RRP1|NBAS   ...    10.376216    10.993136    10.851952    10.741054
# ...           ...          ...          ...          ...          ...
# Q9Y6R0|NUMBL  ...    12.050160    11.571300    11.879640    11.437920
# Q9Y6V0|PCLO   ...     9.621430     9.502433     9.548516     9.563470
# Q9Y6V7|DDX49  ...    11.304200    11.231960    11.141490    11.126730
# Q9Y6X4|F169A  ...    11.143870    11.052500    10.983980    10.591580
# Q9Y6Y0|NS1BP  ...    11.312180    11.462670    11.387050    11.234520
#
#               NEUZT902WVB  NEUZV656DD1  NEUZW701NNF  NEUZX521TKK  NEUZX847VWV  \
# A0FGR8|ESYT2    12.910621    12.714050    12.735538    12.424176    12.612128
# A0MZ66|SHOT1    13.952639    13.839152    13.886002    13.890692    14.014689
# A1L020|MEX3A    13.326455    13.594600    13.468686    13.333949    13.380199
# A1X283|SPD2B    12.773617    12.639890    12.464928    12.403512    12.578225
# A2RRP1|NBAS     10.714822    10.526593    10.841943    10.685329    11.093619
# ...                   ...          ...          ...          ...          ...
# Q9Y6R0|NUMBL    11.575610    11.470200    11.451410    11.440140    11.730790
# Q9Y6V0|PCLO      9.338708     8.864950     9.773427     9.418286     9.690135
# Q9Y6V7|DDX49    11.470240    11.299180    11.152710    10.914820    11.464200
# Q9Y6X4|F169A    10.502900    10.801800    10.800560    10.860360    10.696900
# Q9Y6Y0|NS1BP    11.727480    11.847650    11.683010    11.508490    11.271160
#
#               NEUZY975XKL
# A0FGR8|ESYT2    12.579888
# A0MZ66|SHOT1    13.789265
# A1L020|MEX3A    13.520812
# A1X283|SPD2B    12.743562
# A2RRP1|NBAS     10.819350
# ...                   ...
# Q9Y6R0|NUMBL    11.560100
# Q9Y6V0|PCLO      9.387186
# Q9Y6V7|DDX49    11.410380
# Q9Y6X4|F169A    10.541000
# Q9Y6Y0|NS1BP    11.795790
#
# [3496 rows x 203 columns]

# %%
metadata
# Out:
#                GUID_orig         GUID_vial         GUID  \
# NEUAB000NKC  NEUAB000NKC  NEUAB000NKC_5730  NEUAB000NKC
# NEUAE993EPR  NEUAE993EPR  NEUAE993EPR_6291  NEUAE993EPR
# NEUAF553MJ3  NEUAF553MJ3  NEUAF553MJ3_5888  NEUAF553MJ3
# NEUAG241NUD  NEUAG241NUD  NEUAG241NUD_6685  NEUAG241NUD
# NEUAG603XLK  NEUAG603XLK  NEUAG603XLK_5758  NEUAG603XLK
# ...                  ...               ...          ...
# NEUZV656DD1  NEUZV656DD1  NEUZV656DD1_6056  NEUZV656DD1
# NEUZW701NNF  NEUZW701NNF  NEUZW701NNF_6885  NEUZW701NNF
# NEUZX521TKK  NEUZX521TKK  NEUZX521TKK_5797  NEUZX521TKK
# NEUZX847VWV  NEUZX847VWV  NEUZX847VWV_6091  NEUZX847VWV
# NEUZY975XKL  NEUZY975XKL  NEUZY975XKL_6575  NEUZY975XKL
#
#             attribute_ExperimentalGroup attribute_SampleType  \
# NEUAB000NKC                        Case                 diMN
# NEUAE993EPR                        Case                 diMN
# NEUAF553MJ3                        Case                 diMN
# NEUAG241NUD                        Case                 diMN
# NEUAG603XLK                        Case                 diMN
# ...                                 ...                  ...
# NEUZV656DD1                        Case                 diMN
# NEUZW701NNF                        Case                 diMN
# NEUZX521TKK                        Case                 diMN
# NEUZX847VWV                        Case                 diMN
# NEUZY975XKL                        Case                 diMN
#
#              attribute_TechnicalGroup attribute_Species attribute_DataType  \
# NEUAB000NKC                         1             Human                DIA
# NEUAE993EPR                         1             Human                DIA
# NEUAF553MJ3                         1             Human                DIA
# NEUAG241NUD                         1             Human                DIA
# NEUAG603XLK                         1             Human                DIA
# ...                               ...               ...                ...
# NEUZV656DD1                         1             Human                DIA
# NEUZW701NNF                         1             Human                DIA
# NEUZX521TKK                         1             Human                DIA
# NEUZX847VWV                         1             Human                DIA
# NEUZY975XKL                         1             Human                DIA
#
#               attribute_BiologicalGroup                           Level2  ...  \
# NEUAB000NKC    NEUAB000NKC_5730_MS2-A01    Case_NEUAB000NKC_5730_MS2-A01  ...
# NEUAE993EPR  NEUAE993EPR-6291-P-MS3-C02  Case_NEUAE993EPR-6291-P-MS3-C02  ...
# NEUAF553MJ3      NEUAF553MJ3-5889-P_F12      Case_NEUAF553MJ3-5889-P_F12  ...
# NEUAG241NUD      NEUAG241NUD-6685-P_B07      Case_NEUAG241NUD-6685-P_B07  ...
# NEUAG603XLK      NEUAG603XLK-5759-P_F13      Case_NEUAG603XLK-5759-P_F13  ...
# ...                                 ...                              ...  ...
# NEUZV656DD1    NEUZV656DD1_6056_MS2-C10    Case_NEUZV656DD1_6056_MS2-C10  ...
# NEUZW701NNF      NEUZW701NNF-6885-P_E02      Case_NEUZW701NNF-6885-P_E02  ...
# NEUZX521TKK    NEUZX521TKK_5797_MS2-B01    Case_NEUZX521TKK_5797_MS2-B01  ...
# NEUZX847VWV    NEUZX847VWV_6091_MS2-D02    Case_NEUZX847VWV_6091_MS2-D02  ...
# NEUZY975XKL      NEUZY975XKL-6575-P_A01      Case_NEUZY975XKL-6575-P_A01  ...
#
#             Age At Symptom Onset  Age At Death  ALSFRS-R Baseline  \
# NEUAB000NKC                 50.0          55.0               40.0
# NEUAE993EPR                 55.0           NaN               40.0
# NEUAF553MJ3                 59.0           NaN               27.0
# NEUAG241NUD                 57.0           NaN               38.0
# NEUAG603XLK                 54.0          58.0               40.0
# ...                          ...           ...                ...
# NEUZV656DD1                 35.0          38.0                7.0
# NEUZW701NNF                 64.0          66.0               41.0
# NEUZX521TKK                 70.0          74.0               23.0
# NEUZX847VWV                 55.0          57.0               34.0
# NEUZY975XKL                 46.0           NaN               19.0
#
#             ALSFRS-R Latest  ALSFRS-R Progression Slope     Sex  \
# NEUAB000NKC            31.0                     -0.5590  Female
# NEUAE993EPR            14.0                     -0.8191  Female
# NEUAF553MJ3             NaN                         NaN  Female
# NEUAG241NUD            38.0                         NaN    Male
# NEUAG603XLK            29.0                     -0.7397  Female
# ...                     ...                         ...     ...
# NEUZV656DD1             6.0                         NaN    Male
# NEUZW701NNF            32.0                         NaN    Male
# NEUZX521TKK            16.0                     -0.6519    Male
# NEUZX847VWV            34.0                         NaN    Male
# NEUZY975XKL            16.0                     -0.3881    Male
#
#             Primary Tissue progressor estimated_slope_alsfrsr  SOD1_gen
# NEUAB000NKC    PBMC/T-Cell  AMBIGUOUS               -0.512430       NEG
# NEUAE993EPR    PBMC/T-Cell       fast               -0.822744       NEG
# NEUAF553MJ3   PBMC/NT-Cell        NaN                     NaN       NEG
# NEUAG241NUD   PBMC/NT-Cell        NaN                     NaN       NEG
# NEUAG603XLK   PBMC/NT-Cell  AMBIGUOUS               -0.720656       NEG
# ...                    ...        ...                     ...       ...
# NEUZV656DD1    PBMC/T-Cell        NaN                     NaN       NEG
# NEUZW701NNF            NaN        NaN                     NaN       NEG
# NEUZX521TKK    PBMC/T-Cell  AMBIGUOUS               -0.617298       NEG
# NEUZX847VWV   PBMC/NT-Cell        NaN                     NaN       UNK
# NEUZY975XKL   PBMC/NT-Cell  AMBIGUOUS               -0.232751       NEG
#
# [203 rows x 56 columns]

# %%
# Compute cross subject correlations and estimate "edge weights" from them
corr_matrix = proteomics.corr()

scaled = MinMaxScaler().fit_transform(corr_matrix.values.reshape(-1, 1)).reshape((num_guids, num_guids))
# setting arbitrary threshold for testing purposes
scaled[scaled < 0.75] = 0
np.fill_diagonal(scaled, 0)
scaled
# Out:
# array([[0.        , 0.7866374 , 0.        , ..., 0.87267007, 0.        ,
#         0.78108293],
#        [0.7866374 , 0.        , 0.        , ..., 0.85873462, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.78990535,
#         0.8203059 ],
#        ...,
#        [0.87267007, 0.85873462, 0.        , ..., 0.        , 0.78633743,
#         0.81359922],
#        [0.        , 0.        , 0.78990535, ..., 0.78633743, 0.        ,
#         0.83201771],
#        [0.78108293, 0.        , 0.8203059 , ..., 0.81359922, 0.83201771,
#         0.        ]])

# %%
# Create networkx object
guid_nt = nx.from_numpy_matrix(scaled)
guid_nt = nx.relabel_nodes(guid_nt, dict(zip(np.arange(num_guids), proteomics.columns)))

# Set some attributes from metadata
# Can set other attributes as well
nx.set_node_attributes(guid_nt, metadata.loc[:, ['Case', 'Sex']].to_dict('index'))

# %%
# Set node colors 
add_node_colors(guid_nt, col_attribute='Case')

# %%
guid_nt.nodes['NEUAB000NKC']
# Out:
# {'Case': 'CASE', 'Sex': 'Female', 'color': '#7fc97fff'}

# %%
# Subgraph for ease of visualization
sub_nt = guid_nt.subgraph(list(guid_nt.nodes)[:20])

nt = net.Network('750px', '750px', notebook=True)
# nt.barnes_hut()
nt.from_nx(sub_nt)

nt.show('guids.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# guids.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="guids.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Example with imported networkx object

# %%
nx_file = 'oi_testing/oi_outs/overall_pipeline/promoter_TFs_276_randomization_results_02152023_W_10.00_B_10.00_G_5.00_filtered_5000_res1.0/lv_2.graphml'
test_nx = nx.read_graphml(nx_file)

# %%
# what attributes do we have?

set([k for n in test_nx.nodes for k in test_nx.nodes[n].keys()])
# Out:
# {'Direction',
#  'betweenness',
#  'degree',
#  'direction',
#  'gene_type',
#  'general_function',
#  'general_process',
#  'location',
#  'log2FC',
#  'louvain_clusters',
#  'pathway',
#  'prize',
#  'robustness',
#  'source',
#  'specific_function',
#  'specific_process',
#  'specificity',
#  'terminal',
#  'type'}

# %%
# Set node colors 
add_node_colors(test_nx, col_attribute='source')

# Set some additional visual attributes
# Like gene type (whether it's known ALS gene or not) for shape
shape_map = {'ALS_gene': 'square',
             'non_ALS_gene': 'dot'}

node_shapes = {n: shape_map[val] for (n,val) in nx.get_node_attributes(test_nx, 'gene_type').items()}
nx.set_node_attributes(test_nx, node_shapes, 'shape')

# Set all edges to grey
nx.set_edge_attributes(test_nx, values = 'grey', name='color')

# %%
test_nx.nodes['SYNCRIP']
# Out:
# {'prize': 0.0,
#  'type': 'protein',
#  'direction': nan,
#  'terminal': False,
#  'degree': 11,
#  'betweenness': 0.04831280956838569,
#  'louvain_clusters': '2',
#  'location': 'nucleus',
#  'general_process': 'cellular process',
#  'specific_process': 'cellular response to stimulus',
#  'general_function': 'binding',
#  'specific_function': 'protein binding',
#  'robustness': 0.63,
#  'specificity': 0.05,
#  'gene_type': 'non_ALS_gene',
#  'source': 'Steiner Node',
#  'Direction': nan,
#  'log2FC': nan,
#  'pathway': 'NA',
#  'color': '#386cb0ff',
#  'shape': 'dot'}

# %%
# Add some labels for mouseover/clickover

clusters = nx.get_node_attributes(test_nx, 'louvain_clusters')
locations = nx.get_node_attributes(test_nx, 'location')
robusts = nx.get_node_attributes(test_nx, 'robustness')

node_titles = {n:f"cluster:{v}\nlocation:{locations[n]}\nrobustness:{robusts[n]}" for (n,v) in clusters.items()}
nx.set_node_attributes(test_nx, node_titles, 'title')

# %%
# Plot the interactive network
nt = net.Network('750px', '750px', notebook=True)
# nt.barnes_hut()
nt.from_nx(test_nx)

# Can set some additional features this way

# nt.set_options("""
# var options = {
#   "nodes": {
#     "font": {
#       "size": 25
#     },
#     "color": {
#         "border": "red"
            
#     },
#     "opacity": 0.1
#   }
# }
# """) 

nt.show('nx.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nx.html
#         <iframe
#             width="750px"
#             height="750px"
#             src="nx.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
