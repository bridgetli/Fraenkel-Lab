# %%
import numpy as np
import pandas as pd

import mygene
mg = mygene.MyGeneInfo()

from gprofiler import GProfiler

# %% [markdown]
# # Clean up proteomics gene names
#
# It's important that we use names that can be recognized by gprofiler (official symbols). Sometimes the names provided by the original proteomics files are not the standard protein names.

# %%
proteomics = pd.read_csv('proteomics_norm_regressed.csv', index_col=0)
proteomics
# Out:
#              A0FGR8|ESYT2  A0MZ66|SHOT1  A1L020|MEX3A  A1X283|SPD2B
# NEUAB000NKC     22.132582     24.507411     23.586154     22.036223  \
# NEUAE993EPR     45.221770     49.942097     47.992867     44.671287
# NEUAF553MJ3     90.466199     99.505449     96.181448     89.478639
# NEUAG241NUD     10.385513     11.541707     11.311134     10.565407
# NEUAG603XLK     78.150920     86.235523     83.210501     77.540086
# ...                   ...           ...           ...           ...
# NEUZV656DD1     76.387701     84.133331     81.412423     75.689870
# NEUZW701NNF     32.626740     35.845411     34.654499     32.161300
# NEUZX521TKK    147.457095    162.963788    157.155429    146.113811
# NEUZX847VWV     94.248238    104.138992    100.329561     93.414726
# NEUZY975XKL     86.626817     95.535295     92.387055     86.065217
#
#              A2RRP1|NBAS  A2RTX5|SYTC2  A3KMH1|VWA8  A4FU69|EFCB5
# NEUAB000NKC    19.636499     21.235689    21.162085     21.994284  \
# NEUAE993EPR    38.727244     43.061282    43.126658     44.802182
# NEUAF553MJ3    77.750792     86.307861    86.327695     89.094455
# NEUAG241NUD     8.960294     10.202519    10.252189      9.812732
# NEUAG603XLK    67.211740     74.531838    74.848433     77.274251
# ...                  ...           ...          ...           ...
# NEUZV656DD1    65.207632     72.501190    73.060174     75.407061
# NEUZW701NNF    27.923917     30.928368    30.995164     32.112988
# NEUZX521TKK   126.647587    140.525819   140.904131    145.915530
# NEUZX847VWV    81.200284     89.159079    90.075744     92.527213
# NEUZY975XKL    74.408652     82.345737    82.901157     85.445067
#
#              A5D8V6|VP37C  A6NDG6|PGP  ...  Q9Y6I3|EPN1  Q9Y6K1|DNM3A
# NEUAB000NKC     18.572554   19.546428  ...    22.794974     20.170942  \
# NEUAE993EPR     37.218946   40.198396  ...    46.209381     40.664922
# NEUAF553MJ3     75.449926   79.909911  ...    92.383687     81.819790
# NEUAG241NUD      9.020608    9.151642  ...    10.660789      9.570901
# NEUAG603XLK     65.357872   69.589707  ...    80.069674     70.865702
# ...                   ...         ...  ...          ...           ...
# NEUZV656DD1     63.950561   67.139115  ...    77.704208     69.156955
# NEUZW701NNF     27.226467   29.216991  ...    33.229356     29.621711
# NEUZX521TKK    123.468999  130.762071  ...   150.983318    133.677478
# NEUZX847VWV     78.877753   83.445202  ...    96.237650     85.418751
# NEUZY975XKL     72.504982   76.969176  ...    88.651839     78.601636
#
#              Q9Y6M1|IF2B2  Q9Y6M7|S4A7  Q9Y6M9|NDUB9  Q9Y6R0|NUMBL
# NEUAB000NKC     31.865858    23.810717     25.052458     20.297559  \
# NEUAE993EPR     64.755164    48.430675     51.955469     41.268515
# NEUAF553MJ3    129.313710    96.408258    103.963852     82.451987
# NEUAG241NUD     15.009836    10.965950     11.991511      9.742833
# NEUAG603XLK    111.982013    83.351246     90.094299     71.236734
# ...                   ...          ...           ...           ...
# NEUZV656DD1    109.433913    81.453124     88.013561     69.568112
# NEUZW701NNF     46.459469    34.877228     37.360453     29.600791
# NEUZX521TKK    211.518033   158.182674    170.343933    134.648573
# NEUZX847VWV    134.746305   100.668770    108.703929     86.218236
# NEUZY975XKL    124.043095    92.687454    100.001156     79.122930
#
#              Q9Y6V0|PCLO  Q9Y6V7|DDX49  Q9Y6X4|F169A  Q9Y6Y0|NS1BP
# NEUAB000NKC    16.757836     19.578949     18.792708     20.698066
# NEUAE993EPR    34.178908     39.763795     38.792258     41.300492
# NEUAF553MJ3    68.535644     80.029897     77.127294     83.259135
# NEUAG241NUD     7.760601      9.464367      9.042568      9.742454
# NEUAG603XLK    58.940076     69.183565     66.994363     71.879154
# ...                  ...           ...           ...           ...
# NEUZV656DD1    56.986946     67.456198     65.440478     70.341272
# NEUZW701NNF    24.806402     28.695769     27.869300     29.956008
# NEUZX521TKK   111.470762    130.007192    126.732783    135.556106
# NEUZX847VWV    71.387440     83.463221     80.749254     86.265946
# NEUZY975XKL    65.348891     76.716118     74.081040     79.818795
#
# [196 rows x 3496 columns]

# %%
orig_prot_df = pd.DataFrame([name.split('|') for name in proteomics.columns],
                           columns = ['uniprot', 'original_name'])
orig_prot_df.head()
# Out:
#   uniprot original_name
# 0  A0FGR8         ESYT2
# 1  A0MZ66         SHOT1
# 2  A1L020         MEX3A
# 3  A1X283         SPD2B
# 4  A2RRP1          NBAS

# %%
# Get gene info from MyGene
results = mg.querymany(orig_prot_df.uniprot.values, 
                       scopes=['uniprot'], fields=["symbol"], species="human", 
                       as_dataframe=True, returnall=True)
duplicated = results['dup']
missing = results['missing']
out = results['out']
# add back column
out['uniprot'] = out.index.values
# Out:
# INFO:biothings.client:querying 1-1000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 1001-2000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 2001-3000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 3001-3496...
# INFO:biothings.client:done.
# INFO:biothings.client:Finished.
# WARNING:biothings.client:18 input query terms found dup hits:	[('P12532', 2), ('P22392', 2), ('P49674', 2), ('P62805', 10), ('P68431', 10), ('P69905', 2), ('P8424
# WARNING:biothings.client:5 input query terms found no hit:	['A6NHQ2', 'P0CG12', 'P30042', 'Q58FG1', 'Q9Y4D8']

# %%
# drop duplicates and keep first returned 
prot_df = out.drop_duplicates(subset=['uniprot'])
prot_df.head()
# Out:
#            _id     _score    symbol notfound uniprot
# query
# A0FGR8   57488  19.639704     ESYT2      NaN  A0FGR8
# A0MZ66   57698  20.686556     SHTN1      NaN  A0MZ66
# A1L020   92312  20.684448     MEX3A      NaN  A1L020
# A1X283  285590  19.646774  SH3PXD2B      NaN  A1X283
# A2RRP1   51594  19.641256      NBAS      NaN  A2RRP1

# %%
# Merge and add final name column 
# for 5 uniprot IDs that were not identified by mygene, use the original names from the proteomics team
merged = prot_df.merge(orig_prot_df, how='outer', on='uniprot')
merged['final_name'] = merged.apply(lambda row: row['symbol'] if np.isnan(row['notfound']) else row['original_name'],
                                   axis=1)
merged
# Out:
#          _id     _score    symbol notfound uniprot original_name final_name
# 0      57488  19.639704     ESYT2      NaN  A0FGR8         ESYT2      ESYT2
# 1      57698  20.686556     SHTN1      NaN  A0MZ66         SHOT1      SHTN1
# 2      92312  20.684448     MEX3A      NaN  A1L020         MEX3A      MEX3A
# 3     285590  19.646774  SH3PXD2B      NaN  A1X283         SPD2B   SH3PXD2B
# 4      51594  19.641256      NBAS      NaN  A2RRP1          NBAS       NBAS
# ...      ...        ...       ...      ...     ...           ...        ...
# 3491    9253  19.685020     NUMBL      NaN  Q9Y6R0         NUMBL      NUMBL
# 3492   27445  20.070452      PCLO      NaN  Q9Y6V0          PCLO       PCLO
# 3493   54555  20.074020     DDX49      NaN  Q9Y6V7         DDX49      DDX49
# 3494   26049  20.074020   FAM169A      NaN  Q9Y6X4         F169A    FAM169A
# 3495   10625  20.070452  IVNS1ABP      NaN  Q9Y6Y0         NS1BP   IVNS1ABP
#
# [3496 rows x 7 columns]

# %%
any(pd.isnull(merged.final_name))
# Out:
# False

# %% [markdown]
# # Run gprofiler enrichment with background

# %%
# getting fake list of proteins aritificially enriched for translation
rb_prots = [prot for prot in merged.final_name.values if 'RP' in prot]
rb_prots
# Out:
# ['U2SURP',
#  'PRORP',
#  'ARPC1B',
#  'ARPC2',
#  'ARPC3',
#  'ARPC5',
#  'RRP8',
#  'PRPF3',
#  'PRPSAP2',
#  'NRP2',
#  'MRPL33',
#  'PRPF40A',
#  'RP2',
#  'PRPF6',
#  'RPN1',
#  'RPN2',
#  'RPLP1',
#  'RPLP2',
#  'RPLP0',
#  'SERPINE2',
#  'SRPRA',
#  'SNRPB2',
#  'RPS17',
#  'RPSA',
#  'MRPL3',
#  'SNRPA',
#  'SNRPC',
#  'SNRPA1',
#  'PARP1',
#  'RPS2',
#  'RPA2',
#  'RPL35A',
#  'RPL7',
#  'RPL17',
#  'CSRP1',
#  'RPS3',
#  'RPS12',
#  'RPL13',
#  'RPL10',
#  'RPA1',
#  'ERP29',
#  'RPL12',
#  'LRPAP1',
#  'RPL9',
#  'SERPINB6',
#  'RPA3',
#  'RPL22',
#  'RPL4',
#  'SRP14',
#  'RPS19',
#  'RPL3',
#  'RPL13A',
#  'PRPH',
#  'RPS27',
#  'LRPPRC',
#  'RPL35',
#  'RPL27A',
#  'RPL5',
#  'RPL21',
#  'RPL28',
#  'RPS9',
#  'RPS5',
#  'RPS10',
#  'RPL29',
#  'RPL34',
#  'RPIA',
#  'MRPL19',
#  'SERPINB9',
#  'SERPINH1',
#  'RPL14',
#  'RPS6KA3',
#  'MRPL12',
#  'RRP1',
#  'ARPP19',
#  'ARPC4',
#  'RPS20',
#  'PRPS1',
#  'RPS3A',
#  'RPL26',
#  'RPL15',
#  'RPL27',
#  'RPL37A',
#  'RPS7',
#  'RPS8',
#  'RPS15A',
#  'RPS16',
#  'RPS14',
#  'RPS23',
#  'RPS18',
#  'RPS29',
#  'RPS13',
#  'RPS11',
#  'SNRPE',
#  'SNRPF',
#  'SNRPD1',
#  'SNRPD2',
#  'SNRPD3',
#  'RPL7A',
#  'RPS4X',
#  'RPL23A',
#  'RPS6',
#  'RPL23',
#  'RPS15',
#  'RPS24',
#  'RPS25',
#  'RPS26',
#  'RPS28',
#  'RPL30',
#  'RPL31',
#  'RPL10A',
#  'RPL32',
#  'RPL11',
#  'RPL8',
#  'RPS27A',
#  'RPL38',
#  'RPS21',
#  'RPP30',
#  'SRPX',
#  'MRPS22',
#  'MRPS25',
#  'MRPS10',
#  'MRPS35',
#  'MRPS5',
#  'MRPS36',
#  'MRPS11',
#  'MRPS15',
#  'MRPS21',
#  'MRPS34',
#  'MRPS6',
#  'MRPS9',
#  'RPL24',
#  'RPL36A',
#  'RPL19',
#  'RPL18A',
#  'RPL6',
#  'RPL18',
#  'LRP1',
#  'SSRP1',
#  'MRPL28',
#  'MRPL49',
#  'PRPF4B',
#  'MRPL58',
#  'PRPSAP1',
#  'RRP1B',
#  'CSRP2',
#  'MRPL23',
#  'PARP14',
#  'RRP12',
#  'MRPL2',
#  'RPRD2',
#  'RPL7L1',
#  'MRPL14',
#  'PRPF8',
#  'RPS27L',
#  'MRPL21',
#  'MRPL55',
#  'MRPL41',
#  'RPTOR',
#  'MRPL50',
#  'MRPL43',
#  'PRPF38A',
#  'MRPL30',
#  'PRPF31',
#  'MRPS27',
#  'ARPC1A',
#  'RPL3L',
#  'KHSRP',
#  'RPL36AL',
#  'MRPL24',
#  'MRPL38',
#  'MRPS24',
#  'MRPL53',
#  'MRPL48',
#  'SFRP2',
#  'RPRD1A',
#  'TRPM7',
#  'SRPK1',
#  'SERPINI1',
#  'ARPC5L',
#  'ERP44',
#  'MRPL32',
#  'MRPL20',
#  'MRPL13',
#  'MRPL9',
#  'MRPL1',
#  'MRPS26',
#  'SLIRP',
#  'RPAP3',
#  'RPF2',
#  'MRPL44',
#  'FN3KRP',
#  'GRPEL1',
#  'MRPL47',
#  'MRPS30',
#  'MRPL40',
#  'RPRD1B',
#  'MRPL17',
#  'MRPS18A',
#  'MRPL22',
#  'MRPL16',
#  'MRPL39',
#  'MRPL27',
#  'PRPF19',
#  'RPH3A',
#  'MRPS28',
#  'MRPS17',
#  'MRPS2',
#  'RRP15',
#  'MRPS16',
#  'MRPS23',
#  'RPL36',
#  'FARP1',
#  'SRPRB',
#  'MRPS18B']

# %%
gp = GProfiler(return_dataframe=True)
sourcelist = ["GO:MF","GO:BP","KEGG","REAC"]
enrichment_results = gp.profile(organism='hsapiens',query=rb_prots, 
                                sources=sourcelist, no_evidences = False,
                               background = merged.final_name.values.tolist())

# %%
enrichment_results
# Out:
#     source              native
# 0    GO:MF          GO:0003735  \
# 1     KEGG          KEGG:03010
# 2     REAC    REAC:R-HSA-72766
# 3     REAC  REAC:R-HSA-2408557
# 4     REAC   REAC:R-HSA-192823
# ..     ...                 ...
# 96   GO:MF          GO:1990948
# 97   GO:BP          GO:0140694
# 98   GO:MF          GO:0070181
# 99   GO:MF          GO:0055105
# 100  GO:BP          GO:1904667
#
#                                                   name        p_value
# 0                   structural constituent of ribosome  1.318278e-152  \
# 1                                             Ribosome  7.297676e-140
# 2                                          Translation  1.042139e-124
# 3                             Selenocysteine synthesis   3.353145e-93
# 4                               Viral mRNA Translation   8.597019e-92
# ..                                                 ...            ...
# 96                 ubiquitin ligase inhibitor activity   2.171487e-03
# 97             non-membrane-bounded organelle assembly   7.028106e-03
# 98                small ribosomal subunit rRNA binding   1.444008e-02
# 99    ubiquitin-protein transferase inhibitor activity   1.444008e-02
# 100  negative regulation of ubiquitin protein ligas...   1.444008e-02
#
#      significant                                        description
# 0           True  "The action of a molecule that contributes to ...  \
# 1           True                                           Ribosome
# 2           True                                        Translation
# 3           True                           Selenocysteine synthesis
# 4           True                             Viral mRNA Translation
# ..           ...                                                ...
# 96          True  "Binds to and stops, prevents or reduces the a...
# 97          True  "The aggregation, arrangement and bonding toge...
# 98          True  "Binding to small ribosomal subunit RNA (SSU r...
# 99          True  "Binds to and stops, prevents or reduces the a...
# 100         True  "Any process that stops, prevents or reduces t...
#
#      term_size  query_size  intersection_size  effective_domain_size
# 0          129         212                122                   3536  \
# 1          109         212                108                   3536
# 2          229         212                138                   3536
# 3           79         212                 77                   3536
# 4           80         212                 77                   3536
# ..         ...         ...                ...                    ...
# 96           6         212                  6                   3536
# 97         123         212                 24                   3536
# 98           7         212                  6                   3536
# 99           7         212                  6                   3536
# 100          7         212                  6                   3536
#
#      precision    recall    query                   parents
# 0     0.575472  0.945736  query_1              [GO:0005198]  \
# 1     0.509434  0.990826  query_1              [KEGG:00000]
# 2     0.650943  0.602620  query_1       [REAC:R-HSA-392499]
# 3     0.363208  0.974684  query_1      [REAC:R-HSA-2408522]
# 4     0.363208  0.962500  query_1       [REAC:R-HSA-168273]
# ..         ...       ...      ...                       ...
# 96    0.028302  1.000000  query_1              [GO:0055105]
# 97    0.113208  0.195122  query_1              [GO:0070925]
# 98    0.028302  0.857143  query_1              [GO:0019843]
# 99    0.028302  0.857143  query_1  [GO:0004857, GO:0055106]
# 100   0.028302  0.857143  query_1  [GO:0051444, GO:1904666]
#
#                                          intersections
# 0    [MRPL33, RPLP1, RPLP2, RPLP0, RPS17, RPSA, MRP...  \
# 1    [MRPL33, RPLP1, RPLP2, RPLP0, RPS17, RPSA, MRP...
# 2    [MRPL33, RPN1, RPN2, RPLP1, RPLP2, RPLP0, SRPR...
# 3    [RPLP1, RPLP2, RPLP0, RPS17, RPSA, RPS2, RPL35...
# 4    [RPLP1, RPLP2, RPLP0, RPS17, RPSA, RPS2, RPL35...
# ..                                                 ...
# 96            [RPL5, RPS20, RPS7, RPL23, RPS15, RPL11]
# 97   [RPLP0, RPSA, CSRP1, RPS3, RPL10, RPS19, RPS27...
# 98        [RPS3, RPS14, RPS13, MRPS11, MRPS6, MRPS18A]
# 99            [RPL5, RPS20, RPS7, RPL23, RPS15, RPL11]
# 100           [RPL5, RPS20, RPS7, RPL23, RPS15, RPL11]
#
#                                              evidences
# 0    [[IEA], [IDA, IBA, NAS, IEA], [IDA, NAS, IEA],...
# 1    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2    [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 3    [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 4    [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# ..                                                 ...
# 96          [[IDA], [IDA], [IDA], [IDA], [IDA], [IMP]]
# 97   [[IBA], [IBA, IEA], [IBA], [IMP], [IBA], [IMP,...
# 98          [[IDA], [IBA], [IBA], [IBA], [IBA], [IBA]]
# 99          [[IDA], [IDA], [IDA], [IDA], [IDA], [IMP]]
# 100         [[IDA], [IEA], [IDA], [IDA], [IEA], [IMP]]
#
# [101 rows x 16 columns]

# %%
# notice misleading changes in significance when we use a wider (but less accurate) background
enrichment_results2 = gp.profile(organism='hsapiens',query=rb_prots, 
                                sources=sourcelist, no_evidences = False)
enrichment_results2
# Out:
#     source              native
# 0     REAC    REAC:R-HSA-72766  \
# 1     KEGG          KEGG:03010
# 2    GO:MF          GO:0003735
# 3    GO:BP          GO:0006412
# 4    GO:BP          GO:0043043
# ..     ...                 ...
# 131   REAC  REAC:R-HSA-3928662
# 132  GO:BP          GO:0006015
# 133  GO:BP          GO:0046391
# 134  GO:BP          GO:0006417
# 135  GO:BP          GO:0031397
#
#                                                   name        p_value
# 0                                          Translation  1.788156e-182  \
# 1                                             Ribosome  3.953646e-167
# 2                   structural constituent of ribosome  2.055878e-147
# 3                                          translation  7.991113e-141
# 4                         peptide biosynthetic process  2.082917e-138
# ..                                                 ...            ...
# 131                    EPHB-mediated forward signaling   3.215222e-02
# 132  5-phosphoribose 1-diphosphate biosynthetic pro...   3.906495e-02
# 133    5-phosphoribose 1-diphosphate metabolic process   3.906495e-02
# 134                          regulation of translation   3.985431e-02
# 135      negative regulation of protein ubiquitination   4.059610e-02
#
#      significant                                        description
# 0           True                                        Translation  \
# 1           True                                           Ribosome
# 2           True  "The action of a molecule that contributes to ...
# 3           True  "The cellular metabolic process in which a pro...
# 4           True  "The chemical reactions and pathways resulting...
# ..           ...                                                ...
# 131         True                    EPHB-mediated forward signaling
# 132         True  "The chemical reactions and pathways resulting...
# 133         True  "The chemical reactions and pathways involving...
# 134         True  "Any process that modulates the frequency, rat...
# 135         True  "Any process that stops, prevents, or reduces ...
#
#      term_size  query_size  intersection_size  effective_domain_size
# 0          292         193                138                  10790  \
# 1          153         156                108                   8161
# 2          451         209                122                  20195
# 3          745         212                135                  21110
# 4          774         212                135                  21110
# ..         ...         ...                ...                    ...
# 131         40         193                  6                  10790
# 132          6         212                  3                  21110
# 133          6         212                  3                  21110
# 134        413         212                 15                  21110
# 135         83         212                  7                  21110
#
#      precision    recall    query
# 0     0.715026  0.472603  query_1  \
# 1     0.692308  0.705882  query_1
# 2     0.583732  0.270510  query_1
# 3     0.636792  0.181208  query_1
# 4     0.636792  0.174419  query_1
# ..         ...       ...      ...
# 131   0.031088  0.150000  query_1
# 132   0.014151  0.500000  query_1
# 133   0.014151  0.500000  query_1
# 134   0.070755  0.036320  query_1
# 135   0.033019  0.084337  query_1
#
#                                                parents
# 0                                  [REAC:R-HSA-392499]  \
# 1                                         [KEGG:00000]
# 2                                         [GO:0005198]
# 3     [GO:0009059, GO:0010467, GO:0019538, GO:0043043]
# 4                 [GO:0006518, GO:0043604, GO:1901566]
# ..                                                 ...
# 131                               [REAC:R-HSA-2682334]
# 132                           [GO:0046390, GO:0046391]
# 133                                       [GO:0019693]
# 134  [GO:0006412, GO:0010556, GO:0010608, GO:003132...
# 135               [GO:0016567, GO:0031396, GO:1903321]
#
#                                          intersections
# 0    [MRPL33, RPN1, RPN2, RPLP1, RPLP2, RPLP0, SRPR...  \
# 1    [MRPL33, RPLP1, RPLP2, RPLP0, RPS17, RPSA, MRP...
# 2    [MRPL33, RPLP1, RPLP2, RPLP0, RPS17, RPSA, MRP...
# 3    [MRPL33, RPLP1, RPLP2, RPLP0, RPS17, RPSA, MRP...
# 4    [MRPL33, RPLP1, RPLP2, RPLP0, RPS17, RPSA, MRP...
# ..                                                 ...
# 131       [ARPC1B, ARPC2, ARPC3, ARPC5, ARPC4, ARPC1A]
# 132                          [PRPSAP2, PRPS1, PRPSAP1]
# 133                          [PRPSAP2, PRPS1, PRPSAP1]
# 134  [RPS3, RPL10, RPL13A, LRPPRC, RPL5, RPS9, RPS6...
# 135     [RPS3, RPL5, RPS20, RPS7, RPL23, RPS15, RPL11]
#
#                                              evidences
# 0    [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 1    [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 2    [[IEA], [IDA, IBA, NAS, IEA], [IDA, NAS, IEA],...
# 3    [[NAS, IEA], [IBA, NAS, IC, IEA], [NAS, IEA], ...
# 4    [[NAS, IEA], [IBA, NAS, IC, IEA], [NAS, IEA], ...
# ..                                                 ...
# 131   [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC]]
# 132                         [[IBA], [IBA, IEA], [IBA]]
# 133                         [[IBA], [IBA, IEA], [IBA]]
# 134  [[IDA, IEA], [IMP, IEA], [IDA, IMP, IBA, IEA],...
# 135  [[IDA], [IDA], [IEA], [IDA], [IDA], [IEA], [IMP]]
#
# [136 rows x 16 columns]
